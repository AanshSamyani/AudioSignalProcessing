# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt

# %%
file_path = r"C:\Users\Admin\Desktop\DS203\E7\MFCC-files-v2\01-MFCC.csv"
data_mfcc_1 = np.genfromtxt(file_path, delimiter=',')

# %%
data_mfcc_1.shape
# Out:
# (20, 9769)

# %%
data_few_seconds_1 = data_mfcc_1[:,:500]
data_few_seconds_2 = data_mfcc_1[:,500:1000]
data_few_seconds_3 = data_mfcc_1[:,1000:1500]

# %%
recon_1 = librosa.feature.inverse.mfcc_to_audio(data_few_seconds_1)
recon_2 = librosa.feature.inverse.mfcc_to_audio(data_few_seconds_2)
recon_3 = librosa.feature.inverse.mfcc_to_audio(data_few_seconds_3)

# %%
# ipd.Audio(recon_1, rate=44100)
# ipd.Audio(recon_2, rate=44100)
ipd.Audio(recon_3, rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
